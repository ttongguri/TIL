# %% [markdown]
# # 1. AI, ML, DL의 정의

# %% [markdown]
# - AI와 머신러닝(ML)이 내 일상에 미치는 영향
#
#   ```사람이 모든 규칙을 미리 코딩하지 않아도, 데이터에서 규칙을 학습해 성능 향상.```

# %% [markdown]
# ### AI(Artificial Intelligence)
# - 주어진 환경/데이터를 인지/학습/추론을 통해 목표 달성하도록 예측/행동 선택/계획하는 시스템

# %% [markdown]
# ### ML(Machine Learning)
# - AI 범주 내에서 데이터로부터 학습해 목적을 달성하는 접근 방법론
# - 예: 언어 모델, 이미지 분류 모델, 추천 시스템

# %% [markdown]
# ### DL(Deep Learning)
# - ML 범주 내에서 신경망(Neural Network)함수를 사용한 학습 방법론

# %% [markdown]
# # 2-1. 데이터 구성요소(Feature/Label)

# %% [markdown]
# ```
# 데이터가 왜 중요한가?
# ```
# - 머신러닝은 규칙을 직접 코딩하지 않고, 데이터에서 규칙을 학습
# - 데이터(Feature, Label)의 분포와 관계가 머신러닝의 학습 결과 결정

# %% [markdown]
# ```Feature(피처, 특성)```
# - 모델이 예측에 사용하는 입력정보 (input)
# - 예측, 판단의 근거/단서

# %% [markdown]
# ```Label(라벨, 목표값)```
# - 모델이 예측하려는 정답 (output)
# - 학습의 목표값
